# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/racheldyap/Desktop/BTS - DS Foundations/Session_1/file_formats/rural_population_data.csv")
df.head()
# Out:
#   Continent                          ElevationZone UrbanRuralDesignation  \
# 0    Africa    Elevations > 20m or Non-Contiguous                  Rural
# 1    Africa    Elevations > 20m or Non-Contiguous                  Urban
# 2    Africa  Elevations Less Than or Equal To 10m                  Rural
# 3    Africa  Elevations Less Than or Equal To 10m                  Urban
# 4    Africa  Elevations Less Than or Equal To 12m                  Rural
#
#    Population1990  Population2000  Population2010  Population2100  LandArea
# 0       333302081       418265923       530184094      1249908321  23749644
# 1       157846329       210381843       266776037       504662423    204719
# 2        18167003        22569516        28154645        76368900    172460
# 3        22412955        28679117        36746774        94042536     13838
# 4        20569411        25576481        31957186        85839163    202456

# %%
df.Continent.unique()
# Out:
# array(['Africa', 'Asia', 'Oceania', 'Europe', 'North America',
#        'South America'], dtype=object)

# %%
##### calculate Growrate = (Population2100 - Population2000) / Population2000

# %%
df['Growrate'] = (df.Population2100 - df.Population2000)/df.Population2000
df.head()
# Out:
#   Continent                          ElevationZone UrbanRuralDesignation  \
# 0    Africa    Elevations > 20m or Non-Contiguous                  Rural
# 1    Africa    Elevations > 20m or Non-Contiguous                  Urban
# 2    Africa  Elevations Less Than or Equal To 10m                  Rural
# 3    Africa  Elevations Less Than or Equal To 10m                  Urban
# 4    Africa  Elevations Less Than or Equal To 12m                  Rural
#
#    Population1990  Population2000  Population2010  Population2100  LandArea  \
# 0       333302081       418265923       530184094      1249908321  23749644
# 1       157846329       210381843       266776037       504662423    204719
# 2        18167003        22569516        28154645        76368900    172460
# 3        22412955        28679117        36746774        94042536     13838
# 4        20569411        25576481        31957186        85839163    202456
#
#    growrate  Growrate
# 0  1.988310  1.988310
# 1  1.398793  1.398793
# ...

# %%
import matplotlib.pyplot as plt

df.Growrate.hist()
plt.show()

# %%
### check existence of NaN values in DataFrame

# %%
df.isnull()
# Out:
#      Continent  ElevationZone  UrbanRuralDesignation  Population1990  \
# 0        False          False                  False           False
# 1        False          False                  False           False
# 2        False          False                  False           False
# 3        False          False                  False           False
# 4        False          False                  False           False
# 5        False          False                  False           False
# 6        False          False                  False           False
# 7        False          False                  False           False
# 8        False          False                  False           False
# 9        False          False                  False           False
# 10       False          False                  False           False
# 11       False          False                  False           False
# 12       False          False                  False           False
# ...

# %%
## get average population size in year 2000 & 2010

# %%
df[["Population2000", "Population2010"]].mean(axis=1)
# Out:
# 0      4.742250e+08
# 1      2.385789e+08
# 2      2.536208e+07
# 3      3.271295e+07
# 4      2.876683e+07
# 5      3.758713e+07
# 6      4.338530e+06
# 7      5.353606e+06
# 8      3.921952e+07
# 9      5.429257e+07
# 10     8.675060e+06
# 11     9.884034e+06
# 12     1.390578e+07
# 13     1.646908e+07
# 14     1.895135e+07
# 15     2.344918e+07
# 16     2.351928e+07
# 17     2.994841e+07
# 18     5.134445e+08
# 19     2.928715e+08
# 20     1.886211e+09
# 21     1.218928e+09
# 22     2.226023e+08
# 23     2.714358e+08
# 24     2.573971e+08
# 25     3.113956e+08
# 26     2.148638e+07
# 27     2.091640e+07
# 28     3.515929e+08
# 29     4.281153e+08
#            ...
# 90     1.288992e+06
# 91     4.478976e+06
# 92     2.208515e+06
# 93     8.681017e+06
# 94     3.258066e+06
# 95     1.501713e+07
# 96     4.301280e+06
# 97     2.322812e+07
# 98     1.374807e+08
# 99     3.593046e+08
# 100    1.256424e+08
# 101    1.899454e+08
# 102    4.493669e+06
# 103    1.832880e+07
# ...

# %%
## check number of rows in UrbanRuralDesignation equal to “Urban”

# %%
df.loc[df.loc[:,"UrbanRuralDesignation"]=="Urban"]
# Out:
#          Continent                          ElevationZone  \
# 1           Africa    Elevations > 20m or Non-Contiguous
# 3           Africa  Elevations Less Than or Equal To 10m
# 5           Africa  Elevations Less Than or Equal To 12m
# 7           Africa    Elevations Less Than or Equal To 1m
# 9           Africa  Elevations Less Than or Equal To 20m
# 11          Africa    Elevations Less Than or Equal To 3m
# 13          Africa    Elevations Less Than or Equal To 5m
# 15          Africa    Elevations Less Than or Equal To 7m
# 17          Africa    Elevations Less Than or Equal To 9m
# 19          Africa              Total National Population
# 21            Asia    Elevations > 20m or Non-Contiguous
# 23            Asia  Elevations Less Than or Equal To 10m
# 25            Asia  Elevations Less Than or Equal To 12m
# 27            Asia    Elevations Less Than or Equal To 1m
# 29            Asia  Elevations Less Than or Equal To 20m
# ...

# %%
df.groupby('UrbanRuralDesignation').size()
# Out:
# UrbanRuralDesignation
# Rural    60
# Urban    60
# dtype: int64
