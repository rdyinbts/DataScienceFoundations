# %%
import pandas as pd
import numpy as np

df = pd.read_csv("/Users/racheldyap/Desktop/BTS - DS Foundations/Session_2/2_titanic_dataset.csv", sep=",")
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df1 = df.dropna(axis=0)

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# 21            22         1       2
# 23            24         1       1
# 27            28         0       1
# 52            53         1       1
# 54            55         0       1
# 62            63         0       1
# 66            67         1       2
# 75            76         0       3
# 88            89         1       1
# 92            93         0       1
# 96            97         0       1
# 97            98         1       1
# 102          103         0       1
# 110          111         0       1
# 118          119         0       1
# 123          124         1       2
# 124          125         0       1
# 136          137         1       1
# 137          138         0       1
# 139          140         0       1
# ...

# %%
df.shape
# Out:
# (891, 12)

# %% [markdown]
# ### 1 How many people did and did not survived?

# %%
df.groupby("Survived").size()
# Out:
# Survived
# 0    549
# 1    342
# dtype: int64

# %% [markdown]
# ### 2 What is the minimum age of the passenger?

# %%
df["Age"].min()
# Out:
# 0.41999999999999998

# %% [markdown]
# ### 3 Display the Name of the youngest passenger?

# %%
df[["Name","Age"]].min()
# Out:
# Name    Abbing, Mr. Anthony
# Age                    0.42
# dtype: object

# %% [markdown]
# ### 4 What is the average age of all passengers?

# %%
df["Age"].mean()
# Out:
# 29.69911764705882

# %% [markdown]
# ### 5 What is the maximum age of all passengers?

# %%
df["Age"].max()
# Out:
# 80.0

# %% [markdown]
# ### 6 Where is the most common point of embarkation?

# %%
df.groupby("Embarked").size()
# Out:
# Embarked
# C    168
# Q     77
# S    644
# dtype: int64

# %% [markdown]
# ### 7 How many male passengers were onboard?
# ### 8 How many female passengers were onboard?

# %%
df["Sex"].value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %% [markdown]
# ### 9 How many were in Lower class?
# ### 10 How many were in First class?
# ### 11 How many were in Second class?
# ### 12 Which class did marjority of passengers belong to?
# ### 13 Which class did the minority of passenger belong to?

# %%
df["Pclass"].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %% [markdown]
# ### How much was the most expensive fare paid?

# %%
df.Fare.max()
# Out:
# 512.32920000000001

# %% [markdown]
# ### What was the cheapest fare paid?

# %%
df1.Fare.min()
# Out:
# 0.0

# %% [markdown]
# ### What was the average fare paid?

# %%
df1.Fare.mean()
# Out:
# 78.68246885245901

# %% [markdown]
# ### Who paid the highest fare?

# %%
df[["Name","Fare"]].max()
# Out:
# Name    van Melkebeke, Mr. Philemon
# Fare                        512.329
# dtype: object

# %% [markdown]
# ### Who paid the least fare?

# %%
df[["Name","Fare"]].min()
# Out:
# Name    Abbing, Mr. Anthony
# Fare                      0
# dtype: object

# %% [markdown]
# ### How many total passengers were there?

# %%
df.PassengerId.count()
# Out:
# 891

# %%
np_sex = np.array(df['Sex'])

# %%
# Out:
# numpy.ndarray

# %% [markdown]
# ### How many percentage of passengers are female?¶

# %%
(df.loc[df.loc[:,"Sex"]=="female"].shape[0]/df.shape[0])*100
# Out:
# 35.24130190796858
