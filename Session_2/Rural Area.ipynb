# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/Users/racheldyap/Desktop/DataScienceFoundations/Session_1/file_formats/rural_population_data.csv", sep=",")
df.head()
# Out:
#   Continent                          ElevationZone UrbanRuralDesignation  \
# 0    Africa    Elevations > 20m or Non-Contiguous                  Rural
# 1    Africa    Elevations > 20m or Non-Contiguous                  Urban
# 2    Africa  Elevations Less Than or Equal To 10m                  Rural
# 3    Africa  Elevations Less Than or Equal To 10m                  Urban
# 4    Africa  Elevations Less Than or Equal To 12m                  Rural
#
#    Population1990  Population2000  Population2010  Population2100  LandArea
# 0       333302081       418265923       530184094      1249908321  23749644
# 1       157846329       210381843       266776037       504662423    204719
# 2        18167003        22569516        28154645        76368900    172460
# 3        22412955        28679117        36746774        94042536     13838
# 4        20569411        25576481        31957186        85839163    202456

# %%
df["Continent"].unique()
# Out:
# array(['Africa', 'Asia', 'Oceania', 'Europe', 'North America',
#        'South America'], dtype=object)

# %%
df.shape
# Out:
# (120, 9)

# %%
df["ElevationZone"].unique()
# Out:
# array(['Elevations > 20m or Non-Contiguous ',
#        'Elevations Less Than or Equal To 10m ',
#        'Elevations Less Than or Equal To 12m ',
#        'Elevations Less Than or Equal To 1m',
#        'Elevations Less Than or Equal To 20m ',
#        'Elevations Less Than or Equal To 3m',
#        'Elevations Less Than or Equal To 5m',
#        'Elevations Less Than or Equal To 7m',
#        'Elevations Less Than or Equal To 9m', 'Total National Population'], dtype=object)

# %%
import matplotlib.pyplot as plyt
df['growrate'] = (df.Population2100 - df.Population2000)/df.Population2000
df
# Out:
#          Continent                          ElevationZone  \
# 0           Africa    Elevations > 20m or Non-Contiguous
# 1           Africa    Elevations > 20m or Non-Contiguous
# 2           Africa  Elevations Less Than or Equal To 10m
# 3           Africa  Elevations Less Than or Equal To 10m
# 4           Africa  Elevations Less Than or Equal To 12m
# 5           Africa  Elevations Less Than or Equal To 12m
# 6           Africa    Elevations Less Than or Equal To 1m
# 7           Africa    Elevations Less Than or Equal To 1m
# 8           Africa  Elevations Less Than or Equal To 20m
# 9           Africa  Elevations Less Than or Equal To 20m
# 10          Africa    Elevations Less Than or Equal To 3m
# 11          Africa    Elevations Less Than or Equal To 3m
# 12          Africa    Elevations Less Than or Equal To 5m
# 13          Africa    Elevations Less Than or Equal To 5m
# 14          Africa    Elevations Less Than or Equal To 7m
# ...

# %%
import numpy as np
years = ['1990', '2000', '2010', '2100']
x_yr = np.arange(len(years))
ave_pop = [104537668.49, 120539097.45, 136698712.41, 202861325.46]

# %%
plt.bar(x_yr,ave_pop, align='center', alpha=1)
plt.xticks(x_yr, years)
plt.ylabel('Population in Millions')
plt.title('Average Population per Year')

plt.show()

# %%
## average population per year, by continent

# %%
continents = df.groupby('Continent')
continents.head()
# Out:
#          Continent                          ElevationZone  \
# 0           Africa    Elevations > 20m or Non-Contiguous
# 1           Africa    Elevations > 20m or Non-Contiguous
# 2           Africa  Elevations Less Than or Equal To 10m
# 3           Africa  Elevations Less Than or Equal To 10m
# 4           Africa  Elevations Less Than or Equal To 12m
# 20            Asia    Elevations > 20m or Non-Contiguous
# 21            Asia    Elevations > 20m or Non-Contiguous
# 22            Asia  Elevations Less Than or Equal To 10m
# 23            Asia  Elevations Less Than or Equal To 10m
# 24            Asia  Elevations Less Than or Equal To 12m
# 40         Oceania    Elevations > 20m or Non-Contiguous
# 41         Oceania  Elevations Less Than or Equal To 10m
# 42         Oceania  Elevations Less Than or Equal To 12m
# 43         Oceania    Elevations Less Than or Equal To 1m
# 44         Oceania  Elevations Less Than or Equal To 20m
# ...

# %%
##average land area per region

# %%
plt.figure()
sns.barplot("Continent","LandArea", data=df)

plt.show()

# %%
## 3 variables

# %%
sns.pointplot(x="Continent", y="LandArea", hue="UrbanRuralDesignation", data=df, palette={"Urban":"blue", "Rural":"green"})
plt.show()

# %%
plt.figure(figsize=[12,10])
sns.swarmplot(x="UrbanRuralDesignation", y='ElevationZone', data=df)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-121-55282c25b8d3> in <module>()
#       1 plt.figure(figsize=[12,10])
# ----> 2 sns.swarmplot(x="UrbanRuralDesignation", y='ElevationZone', data=df)
#       3 plt.show()
#
# /anaconda/lib/python3.6/site-packages/seaborn/categorical.py in swarmplot(x, y, hue, data, order, hue_order, split, orient, color, palette, size, edgecolor, linewidth, ax, **kwargs)
#    2723
#    2724     plotter = _SwarmPlotter(x, y, hue, data, order, hue_order,
# -> 2725                             split, orient, color, palette)
#    2726     if ax is None:
#    2727         ax = plt.gca()
#
# /anaconda/lib/python3.6/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, split, orient, color, palette)
#    1181                  split, orient, color, palette):
#    1182         """Initialize the plotter."""
# ...

# %%
sns.factorplot("Continent", "Population2100", "UrbanRuralDesignation", data=df, kind='bar', palette="muted", legend=True, size=4, aspect=2)
plt.show()
