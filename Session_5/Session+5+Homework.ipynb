# %%
import nltk
from nltk import word_tokenize
import os

# %%
os.chdir('/Users/racheldyap/Desktop/DataScienceFoundations/Session_5')

# %%
os.getcwd()
# Out:
# '/Users/racheldyap/Desktop/DataScienceFoundations/Session_5'

# %%
for file in os.listdir('/Users/racheldyap/Desktop/DataScienceFoundations/Session_5'):
    print(file)
# Out:
# .DS_Store
# .ipynb_checkpoints
# 7 Days.txt
# Booty Man.txt
# BTS Data Science Foundations_Session_5_Assignments.pdf
# BTS Data Science Foundations_Session_5_Lecture.pdf
# Can't Be Messing 'Round.txt
# Fill Me In.txt
# Last Night.txt
# Rendezvous.txt
# Rewind.txt
# session_5.ipynb
# session_5_Notes.ipynb

# %%
with open('7 Days.txt') as file:
    song1 = file.read().replace('\n', ' ')

# %%
with open('Booty Man.txt') as file:
    song2 = file.read().replace('\n', ' ')

# %%
with open('Fill Me In.txt') as file:
    song3 = file.read().replace('\n', ' ')

# %%
with open('Last Night.txt') as file:
    song4 = file.read().replace('\n', ' ')

# %%
with open('Can\'t Be Messing \'Round.txt') as file:
    song5 = file.read().replace('\n', ' ')

# %%
with open('Rendezvous.txt') as file:
    song6= file.read().replace('\n', ' ')

# %%
with open('Rewind.txt') as file:
    song7 = file.read().replace('\n', ' ')

# %%
all_songs = [song1, song2, song3, song4, song5, song6, song7]

# %%
songs_tokenize = [word_tokenize(s) for s in all_songs]

# %%
def term_frequency(term, tokenized_document):
    return tokenized_document.count(term)

# %%
def augmented_term_frequency(term, tokenized_document):
    max_count = max([term_frequency(t, tokenized_document) for t in tokenized_document])
    return (0.5 + ((0.5 * term_frequency(term, tokenized_document))/max_count))

# %%
import math
def inverse_document_frequencies(tokenized_documents):
    idf_values = {}
    all_tokens_set = set([item for sublist in tokenized_documents for item in sublist])
    for tkn in all_tokens_set:
        contains_token = map(lambda doc: tkn in doc, tokenized_documents)
        idf_values[tkn] = 1 + math.log(len(tokenized_documents)/(sum(contains_token)))
    return idf_values

# %%
idf_values = inverse_document_frequencies(songs_tokenize)

# %%
print(idf_values['the'])
# Out:
# 1.0

# %%
# 5 Examples of Salient Words

# %%
idf_values['Friday']
# Out:
# 2.9459101490553135

# %%
idf_values['tonight']
# Out:
# 2.252762968495368

# %%
idf_values['crazy']
# Out:
# 2.9459101490553135

# %%
idf_values['wine']
# Out:
# 2.9459101490553135

# %%
idf_values['profile']
# Out:
# 2.9459101490553135

# %%
# TF-IDF score for each lyric

# %%
def tfidf(documents):
    tokenized_documents = [word_tokenize(d) for d in documents]
    idf = inverse_document_frequencies(tokenized_documents)
    tfidf_documents = []
    for document in tokenized_documents:
        doc_tfidf = []
        for term in idf.keys():
            tf = augmented_term_frequency(term, document)
            doc_tfidf.append([term,tf * idf[term]])
        tfidf_documents.append(doc_tfidf)
    return tfidf_documents

# %%
tf_idf = tfidf(all_songs)

# %%
tf_idf[0]
# Out:
# [['She', 1.448204765461308],
#  ['found', 1.4729550745276567],
#  ['David', 0.9236489301936018],
#  ['honey', 1.5430957923623072],
#  ['Is', 1.4729550745276567],
#  ['couple', 1.5430957923623072],
#  ['But', 1.4729550745276567],
#  ['lived', 1.5430957923623072],
#  ['Why', 1.4729550745276567],
#  ['...', 1.0116154949739449],
#  ['aged', 1.5430957923623072],
#  ['where', 0.7798078939677113],
#  ['crazy', 1.4729550745276567],
#  ['same', 1.4729550745276567],
#  ['figure', 1.4729550745276567],
#  ['Tonight', 1.4729550745276567],
#  ['jacket', 1.4729550745276567],
#  ["'Round", 1.4729550745276567],
#  ['six', 1.5430957923623072],
#  ['goin', 1.4729550745276567],
#  ['mans', 1.4729550745276567],
#  ['two', 0.9676322125837734],
#  ['Checkin', 1.4729550745276567],
#  ['start', 0.9676322125837734],
#  ['What', 1.233655911318892],
#  ['bedroom', 1.4729550745276567],
#  ['?', 1.2315319069248023],
#  ['her', 0.9546230261580093],
#  ['years', 1.4729550745276567],
# ...
