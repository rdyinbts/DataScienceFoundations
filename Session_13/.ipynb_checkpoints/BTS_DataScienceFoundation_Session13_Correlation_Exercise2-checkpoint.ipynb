# %% [markdown]
# # Subject: Data Science Foundation
#
# ## Session 13 - Correlation in Python.
#
# ### Exercise 2 -  Calculating Correlation in Pandas

# %% [markdown]
# We will be using a dataset "Boston house prices". Calculate the Pearson correlation between "MEDV-Median value of owner-occupied homes in $1000's)" and all the variables.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import datasets 
data = datasets.load_boston()

# %%
df = pd.DataFrame(data.data, columns=data.feature_names)
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
target = pd.DataFrame(data.target, columns=["MEDV"]) 
target.head()
# Out:
#    MEDV
# 0  24.0
# 1  21.6
# 2  34.7
# 3  33.4
# 4  36.2

# %%
print (data.DESCR)
# Out:
# Boston House Prices dataset
# ...
#
# Notes
# ------
# Data Set Characteristics:
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive
#
#     :Median Value (attribute 14) is usually the target
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
#         - TAX      full-value property-tax rate per $10,000
# ...

# %%
df2 = df.assign(target=target.values)
df2.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  target
# 0     15.3  396.90   4.98    24.0
# 1     17.8  396.90   9.14    21.6
# 2     17.8  392.83   4.03    34.7
# 3     18.7  394.63   2.94    33.4
# 4     18.7  396.90   5.33    36.2

# %%
df2.rename(columns={'target': 'MEDV'}, inplace=True)
df2.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
df2.corr(method='pearson')
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.199458  0.404471 -0.055295  0.417521 -0.219940  0.350784
# ZN      -0.199458  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.404471 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055295 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.417521 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219940  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.350784 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.377904  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.622029 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.579564 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.288250 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
df2.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'),axis=1)
# Out:
# <style  type="text/css" >
#     #T_ad98414a_cec6_11e7_bbda_c4b3018be53crow0_col0 {
#             background-color:  #b40426;
#         }    #T_ad98414a_cec6_11e7_bbda_c4b3018be53crow0_col1 {
#             background-color:  #6485ec;
#         }    #T_ad98414a_cec6_11e7_bbda_c4b3018be53crow0_col2 {
#             background-color:  #edd2c3;
#         }    #T_ad98414a_cec6_11e7_bbda_c4b3018be53crow0_col3 {
#             background-color:  #89acfd;
#         }    #T_ad98414a_cec6_11e7_bbda_c4b3018be53crow0_col4 {
#             background-color:  #efcfbf;
#         }    #T_ad98414a_cec6_11e7_bbda_c4b3018be53crow0_col5 {
#             background-color:  #5f7fe8;
#         }    #T_ad98414a_cec6_11e7_bbda_c4b3018be53crow0_col6 {
#             background-color:  #e5d8d1;
#         }    #T_ad98414a_cec6_11e7_bbda_c4b3018be53crow0_col7 {
#             background-color:  #3c4ec2;
#         }    #T_ad98414a_cec6_11e7_bbda_c4b3018be53crow0_col8 {
#             background-color:  #f6a283;
# ...

# %%
corr = df2.corr(method='pearson')

mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

f, ax = plt.subplots(figsize=(12, 8))
cmap = sns.diverging_palette(220, 10, as_cmap=True)
sns.heatmap(corr, mask=mask, cmap=cmap,vmax=.3,center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %% [markdown]
# # Conclusion:

# %% [markdown]
# MEDV-Median value of owner-occupied homes
#
# Those variables that have a positive correlation with MEDV are:
# - RM
# - ZN
# - B
# - DIS
# - CHAS
#
#
# Negative correlation:
# - LSTAT
# - PTRATIO
# - INDUS
# - TAX
# - NOX
# - CrIM
# - AGE
# - RAD

# %% [markdown]
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
#         - TAX      full-value property-tax rate per $10,000
#         - PTRATIO  pupil-teacher ratio by town
#         - B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#         - LSTAT    % lower status of the population
#         - MEDV     Median value of owner-occupied homes in $1000's

# %% [markdown]
# For determining what causes the Median Value of owner occupied homes,
# the strongest correlation would be determined by:
#
# - LSTAT (lower stat of population) - the higher the lower stat of pop, the lower the MEDV
#
# - RM (ave number of rooms per dwelling): the more the rooms, the higher the value of the house

# %% [markdown]
# ?? Question
#
# - On B - Is it correct that accdg to results above, the higher the B (black population in town), the higher the value of homes?
#
# - On PTRATIO - so if you would put more schools in the town, it would (hopefully) lower the student-teacher ratio, thus would make prices in this town, higher? Is that the correct understanding?
#
# - on AGE - negative correlation means that the older the building was built (<1940) the higher the value of house, right?

# %% [markdown]
# Thus if you were to sell homes at a higher price, the area should more or less have:
#
#     - more rooms per household
#     - residential lands size starting at 25,000 sq.ft.
#     - more black people
#     - more higher status/income dwellers
#     - more schools (to achieve lower student-teacher ratio)
#     - lesser non-retail businesses in town

# %% [markdown]
# Is that correct?
