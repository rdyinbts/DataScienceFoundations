# %% [markdown]
# # Subject: Data Science Foundation
#
# ## Session 13 - Correlation in Python.
#
# ### Exercise 2 -  Calculating Correlation in Pandas

# %% [markdown]
# We will be using a dataset "Boston house prices". Calculate the Pearson correlation between "MEDV-Median value of owner-occupied homes in $1000's)" and all the variables.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import datasets 
data = datasets.load_boston()

# %%
df = pd.DataFrame(data.data, columns=data.feature_names)
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT
# 0     15.3  396.90   4.98
# 1     17.8  396.90   9.14
# 2     17.8  392.83   4.03
# 3     18.7  394.63   2.94
# 4     18.7  396.90   5.33

# %%
target = pd.DataFrame(data.target, columns=["MEDV"]) 
target.head()
# Out:
#    MEDV
# 0  24.0
# 1  21.6
# 2  34.7
# 3  33.4
# 4  36.2

# %%
print (data.DESCR)
# Out:
# Boston House Prices dataset
# ===========================
#
# Notes
# ------
# Data Set Characteristics:
#
#     :Number of Instances: 506
#
#     :Number of Attributes: 13 numeric/categorical predictive
#
#     :Median Value (attribute 14) is usually the target
#
#     :Attribute Information (in order):
#         - CRIM     per capita crime rate by town
#         - ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
#         - INDUS    proportion of non-retail business acres per town
#         - CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
#         - NOX      nitric oxides concentration (parts per 10 million)
#         - RM       average number of rooms per dwelling
#         - AGE      proportion of owner-occupied units built prior to 1940
#         - DIS      weighted distances to five Boston employment centres
#         - RAD      index of accessibility to radial highways
#         - TAX      full-value property-tax rate per $10,000
#         - PTRATIO  pupil-teacher ratio by town
#         - B        1000(Bk - 0.63)^2 where Bk is the proportion of blacks by town
#         - LSTAT    % lower status of the population
#         - MEDV     Median value of owner-occupied homes in $1000's
#
#     :Missing Attribute Values: None
#
#     :Creator: Harrison, D. and Rubinfeld, D.L.
#
# This is a copy of UCI ML housing dataset.
# http://archive.ics.uci.edu/ml/datasets/Housing
#
#
# This dataset was taken from the StatLib library which is maintained at Carnegie Mellon University.
#
# The Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic
# prices and the demand for clean air', J. Environ. Economics & Management,
# vol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics
# ...', Wiley, 1980.   N.B. Various transformations are used in the table on
# pages 244-261 of the latter.
#
# The Boston house-price data has been used in many machine learning papers that address regression
# problems.
#
# **References**
#
#    - Belsley, Kuh & Welsch, 'Regression diagnostics: Identifying Influential Data and Sources of Collinearity', Wiley, 1980. 244-261.
#    - Quinlan,R. (1993). Combining Instance-Based and Model-Based Learning. In Proceedings on the Tenth International Conference of Machine Learning, 236-243, University of Massachusetts, Amherst. Morgan Kaufmann.
#    - many more! (see http://archive.ics.uci.edu/ml/datasets/Housing)

# %%
df2 = df.assign(target=target.values)
df2.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  target
# 0     15.3  396.90   4.98    24.0
# 1     17.8  396.90   9.14    21.6
# 2     17.8  392.83   4.03    34.7
# 3     18.7  394.63   2.94    33.4
# 4     18.7  396.90   5.33    36.2

# %%
df2.rename(columns={'target': 'MEDV'}, inplace=True)
df2.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
df2.corr(method='pearson')
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.199458  0.404471 -0.055295  0.417521 -0.219940  0.350784
# ZN      -0.199458  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.404471 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055295 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.417521 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219940  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.350784 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.377904  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.622029 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.579564 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.288250 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# B       -0.377365  0.175520 -0.356977  0.048788 -0.380051  0.128069 -0.273534
# LSTAT    0.452220 -0.412995  0.603800 -0.053929  0.590879 -0.613808  0.602339
# MEDV    -0.385832  0.360445 -0.483725  0.175260 -0.427321  0.695360 -0.376955
#
#               DIS       RAD       TAX   PTRATIO         B     LSTAT      MEDV
# CRIM    -0.377904  0.622029  0.579564  0.288250 -0.377365  0.452220 -0.385832
# ZN       0.664408 -0.311948 -0.314563 -0.391679  0.175520 -0.412995  0.360445
# INDUS   -0.708027  0.595129  0.720760  0.383248 -0.356977  0.603800 -0.483725
# CHAS    -0.099176 -0.007368 -0.035587 -0.121515  0.048788 -0.053929  0.175260
# NOX     -0.769230  0.611441  0.668023  0.188933 -0.380051  0.590879 -0.427321
# RM       0.205246 -0.209847 -0.292048 -0.355501  0.128069 -0.613808  0.695360
# AGE     -0.747881  0.456022  0.506456  0.261515 -0.273534  0.602339 -0.376955
# DIS      1.000000 -0.494588 -0.534432 -0.232471  0.291512 -0.496996  0.249929
# RAD     -0.494588  1.000000  0.910228  0.464741 -0.444413  0.488676 -0.381626
# TAX     -0.534432  0.910228  1.000000  0.460853 -0.441808  0.543993 -0.468536
# PTRATIO -0.232471  0.464741  0.460853  1.000000 -0.177383  0.374044 -0.507787
# B        0.291512 -0.444413 -0.441808 -0.177383  1.000000 -0.366087  0.333461
# LSTAT   -0.496996  0.488676  0.543993  0.374044 -0.366087  1.000000 -0.737663
# MEDV     0.249929 -0.381626 -0.468536 -0.507787  0.333461 -0.737663  1.000000

# %%
df2.corr(method='pearson').style.format("{:.2}").background_gradient(cmap=plt.get_cmap('coolwarm'),axis=1)
# Out:
# <style  type="text/css" >
#     #T_47361ffe_c86c_11e7_b175_c4b3018be53crow0_col0 {
#             background-color:  #b40426;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow0_col1 {
#             background-color:  #6485ec;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow0_col2 {
#             background-color:  #edd2c3;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow0_col3 {
#             background-color:  #89acfd;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow0_col4 {
#             background-color:  #efcfbf;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow0_col5 {
#             background-color:  #5f7fe8;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow0_col6 {
#             background-color:  #e5d8d1;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow0_col7 {
#             background-color:  #3c4ec2;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow0_col8 {
#             background-color:  #f6a283;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow0_col9 {
#             background-color:  #f7ad90;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow0_col10 {
#             background-color:  #d9dce1;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow0_col11 {
#             background-color:  #3c4ec2;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow0_col12 {
#             background-color:  #f2cab5;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow0_col13 {
#             background-color:  #3b4cc0;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow1_col0 {
#             background-color:  #88abfd;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow1_col1 {
#             background-color:  #b40426;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow1_col2 {
#             background-color:  #4055c8;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow1_col3 {
#             background-color:  #aac7fd;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow1_col4 {
#             background-color:  #445acc;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow1_col5 {
#             background-color:  #ebd3c6;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow1_col6 {
#             background-color:  #3b4cc0;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow1_col7 {
#             background-color:  #f08a6c;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow1_col8 {
#             background-color:  #6f92f3;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow1_col9 {
#             background-color:  #6e90f2;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow1_col10 {
#             background-color:  #5e7de7;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow1_col11 {
#             background-color:  #d6dce4;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow1_col12 {
#             background-color:  #5977e3;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow1_col13 {
#             background-color:  #f1cdba;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow2_col0 {
#             background-color:  #f6bda2;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow2_col1 {
#             background-color:  #5a78e4;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow2_col2 {
#             background-color:  #b40426;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow2_col3 {
#             background-color:  #cfdaea;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow2_col4 {
#             background-color:  #e16751;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow2_col5 {
#             background-color:  #7699f6;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow2_col6 {
#             background-color:  #ef886b;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow2_col7 {
#             background-color:  #3b4cc0;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow2_col8 {
#             background-color:  #f39475;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow2_col9 {
#             background-color:  #e67259;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow2_col10 {
#             background-color:  #f5c0a7;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow2_col11 {
#             background-color:  #7da0f9;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow2_col12 {
#             background-color:  #f29274;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow2_col13 {
#             background-color:  #6384eb;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow3_col0 {
#             background-color:  #4c66d6;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow3_col1 {
#             background-color:  #4f69d9;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow3_col2 {
#             background-color:  #6f92f3;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow3_col3 {
#             background-color:  #b40426;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow3_col4 {
#             background-color:  #779af7;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow3_col5 {
#             background-color:  #779af7;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow3_col6 {
#             background-color:  #7699f6;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow3_col7 {
#             background-color:  #4055c8;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow3_col8 {
#             background-color:  #5a78e4;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow3_col9 {
#             background-color:  #516ddb;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow3_col10 {
#             background-color:  #3b4cc0;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow3_col11 {
#             background-color:  #6a8bef;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow3_col12 {
#             background-color:  #4c66d6;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow3_col13 {
#             background-color:  #92b4fe;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow4_col0 {
#             background-color:  #f7b79b;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow4_col1 {
#             background-color:  #6788ee;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow4_col2 {
#             background-color:  #e0654f;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow4_col3 {
#             background-color:  #d9dce1;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow4_col4 {
#             background-color:  #b40426;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow4_col5 {
#             background-color:  #92b4fe;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow4_col6 {
#             background-color:  #e36c55;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow4_col7 {
#             background-color:  #3b4cc0;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow4_col8 {
#             background-color:  #f18d6f;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow4_col9 {
#             background-color:  #ec7f63;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow4_col10 {
#             background-color:  #e7d7ce;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow4_col11 {
#             background-color:  #82a6fb;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow4_col12 {
#             background-color:  #f29274;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow4_col13 {
#             background-color:  #799cf8;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow5_col0 {
#             background-color:  #8badfd;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow5_col1 {
#             background-color:  #edd1c2;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow5_col2 {
#             background-color:  #6687ed;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow5_col3 {
#             background-color:  #cbd8ee;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow5_col4 {
#             background-color:  #799cf8;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow5_col5 {
#             background-color:  #b40426;
#         }    #T_47361ffe_c86c_11e7_b175_c4b3018be53crow5_co

# %% [markdown]
# # Conclusion:
